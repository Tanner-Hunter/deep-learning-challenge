# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head(50)
# Out:
#          EIN                                               NAME  \
# 0   10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1   10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2   10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3   10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4   10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# 5   10556855  MINORITY ORGAN & TISSUE TRANSPLANT & EDUCATION...
# 6   10558440  FRIENDS OF ARTS COUNCIL OF GREATER DENHAM SPRI...
# 7   10566033                          ISRAEL EMERGENCY ALLIANCE
# 8   10570430                                   ARAMCO BRATS INC
# 9   10571689         INTERNATIONAL ASSOCIATION OF FIRE FIGHTERS
# 10  10573059                      KAI ELUA OUTRIGGER CANOE CLUB
# 11  10575727                                   HERITAGE ACADEMY
# 12  10583569                   THE UNITED STATES PONY CLUBS INC
# 13  10585206  DOMINION INTERNATIONAL NETWORK OF MINISTRIES &...
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAM
df = application_df.drop(["EIN", 'NAME'], axis = 1)

# %%
# Determine the number of unique values in each column
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
df.APPLICATION_TYPE.value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T17','T29','T15','T14','T25','T2','T12','T13','T9']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
count = df.CLASSIFICATION.value_counts(ascending=True)

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
count.head(60)
# Out:
# C1728     1
# C1370     1
# C4200     1
# C6100     1
# C2170     1
# C1732     1
# C1283     1
# C2190     1
# C2150     1
# C1820     1
# C2570     1
# C4500     1
# C1900     1
# C3700     1
# C2380     1
# C1245     1
# C2561     1
# C4120     1
# C1580     1
# C5200     1
# C2500     1
# C1570     1
# C2600     1
# C8210     1
# C1236     1
# C1248     1
# C3200     2
# C1267     2
# C1256     2
# C1246     2
# C1234     2
# C1260     3
# C0        3
# C2710     3
# C1257     5
# C1600     5
# C4100     6
# C2400     6
# C1720     6
# C7210     7
# C1237     9
# C1235     9
# C1238    10
# C1278    10
# C8200    11
# C1250    14
# C6000    15
# C1800    15
# C1500    16
# C7120    18
# C8000    20
# C1240    30
# C7200    32
# C2300    32
# C1400    34
# C1230    36
# C1280    50
# C1300    58
# C7100    75
# C2800    95
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(count[count < 1882].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df2 = pd.get_dummies(df, columns = ['APPLICATION_TYPE','AFFILIATION' , 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION','INCOME_AMT','SPECIAL_CONSIDERATIONS'])

# %%
# Split our preprocessed data into our features and target arrays
# Split the data into feature and target data
X = pd.DataFrame(df2.drop(['IS_SUCCESSFUL'], axis = 1))

y = pd.array(df2['IS_SUCCESSFUL'])
# Split the preprocessed data into a training and testing dataset
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=444)
X_train
# Out:
#        STATUS  ASK_AMT  APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  \
# 30356       1   500321                     0                     0
# 32578       1     5000                     0                     0
# 5007        1   681503                     0                     0
# 31085       1     5000                     0                     0
# 27640       1     5000                     0                     0
# ...       ...      ...                   ...                   ...
# 5615        1     5000                     0                     0
# 4790        1  4149537                     0                     0
# 6631        1     5000                     0                     0
# 25367       1     5000                     0                     0
# 23939       1   101930                     0                     0
#
#        APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  APPLICATION_TYPE_T15  \
# 30356                     0                     0                     0
# ...

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 9
hidden_nodes_layer2 = 18

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 9)                 1053
#
#  dense_1 (Dense)             (None, 18)                180
#
#  dense_2 (Dense)             (None, 1)                 19
#
# ...
# Total params: 1,252
# Trainable params: 1,252
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
y_test = np.array(y_test)
y_train = np.array(y_train)
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5944 - accuracy: 0.7112
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5620 - accuracy: 0.7264
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5560 - accuracy: 0.7273
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5531 - accuracy: 0.7278
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7307
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5504 - accuracy: 0.7303
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5497 - accuracy: 0.7311
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5483 - accuracy: 0.7320
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5480 - accuracy: 0.7307
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8575/8575 - 0s - loss: 0.5578 - acc: 0.7263
# Loss: 0.557812534073699, Accuracy: 0.7262973785400391

# %%
# Export our model to HDF5 file
nn.save('Resources/AlphabetSoupCharity.h5')
